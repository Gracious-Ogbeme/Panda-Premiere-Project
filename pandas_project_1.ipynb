# %% [markdown]
# ***Loading Data***

# %%
# Importing libraries for analysis

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("Clean Dataset.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  19 non-null     object
#  1   1999          19 non-null     float64
#  2   2000          19 non-null     float64
#  3   2001          19 non-null     float64
#  4   2002          19 non-null     float64
#  5   2003          19 non-null     float64
#  6   2004          19 non-null     float64
#  7   2005          19 non-null     float64
#  8   2006          19 non-null     float64
#  9   2007          19 non-null     float64
#  10  2008          19 non-null     float64
#  11  2009          19 non-null     float64
#  12  2010          19 non-null     float64
#  13  2011          19 non-null     float64
#  14  2012          19 non-null     float64
#  15  2013          19 non-null     float64
#  16  2014          19 non-null     float64
# ...

# %% [markdown]
# ***Exploratory Data Analysis***

# %%
data.head()
# Out:
#     Country Name     1999     2000     2001     2002     2003     2004  \
# 0      Argentina  4.52168  4.58031  4.83374  4.01734  3.53505  3.48652
# 1        Austria  6.11234  5.58881  5.57548  5.52213  5.36183  5.30243
# 2    Switzerland  4.75953  4.65878  4.82219  5.17881  5.38401  5.31429
# 3  Cote d'Ivoire  2.68529  2.40031  2.44477  2.81048  2.86437  2.91176
# 4         Cyprus  4.77208  4.98954  5.11552  5.58167  6.67023  6.11772
#
#       2005     2006     2007  ...      2012     2013     2014     2015  \
# 0  3.86001  4.12821  4.46260  ...  5.345830  5.43661  5.36144  5.77611
# 1  5.24937  5.22652  5.14690  ...  5.480400  5.54711  5.44762  5.45658
# 2  5.08472  4.84121  4.58395  ...  4.898620  4.91393  4.93057  4.99559
# 3  2.91944  2.82000  3.01614  ...  3.434470  3.45860  3.31417  3.49413
# 4  6.28667  6.33027  6.28083  ...  5.911855  6.46747  6.42111  6.30491
#
#       2016     2017      2018     2019     2020      2021
# ...

# %%
data.columns
# Out:
# Index(['Country Name', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
years = data.columns[1:]
years
# Out:
# Index(['1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
# Add yearly average as a new column to the dataframe

data['Yearly Average'] = data.loc[:, years].mean(axis=1)

# %%
data.head()
# Out:
#     Country Name     1999     2000     2001     2002     2003     2004  \
# 0      Argentina  4.52168  4.58031  4.83374  4.01734  3.53505  3.48652
# 1        Austria  6.11234  5.58881  5.57548  5.52213  5.36183  5.30243
# 2    Switzerland  4.75953  4.65878  4.82219  5.17881  5.38401  5.31429
# 3  Cote d'Ivoire  2.68529  2.40031  2.44477  2.81048  2.86437  2.91176
# 4         Cyprus  4.77208  4.98954  5.11552  5.58167  6.67023  6.11772
#
#       2005     2006     2007  ...     2013     2014     2015     2016  \
# 0  3.86001  4.12821  4.46260  ...  5.43661  5.36144  5.77611  5.54549
# 1  5.24937  5.22652  5.14690  ...  5.54711  5.44762  5.45658  5.47962
# 2  5.08472  4.84121  4.58395  ...  4.91393  4.93057  4.99559  4.98164
# 3  2.91944  2.82000  3.01614  ...  3.45860  3.31417  3.49413  3.93593
# 4  6.28667  6.33027  6.28083  ...  6.46747  6.42111  6.30491  6.11811
#
#       2017      2018     2019     2020      2021  Yearly Average
# ...

# %%
# Showing the information about the data type

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    19 non-null     object
#  1   1999            19 non-null     float64
#  2   2000            19 non-null     float64
#  3   2001            19 non-null     float64
#  4   2002            19 non-null     float64
#  5   2003            19 non-null     float64
#  6   2004            19 non-null     float64
#  7   2005            19 non-null     float64
#  8   2006            19 non-null     float64
#  9   2007            19 non-null     float64
#  10  2008            19 non-null     float64
#  11  2009            19 non-null     float64
#  12  2010            19 non-null     float64
#  13  2011            19 non-null     float64
#  14  2012            19 non-null     float64
#  15  2013            19 non-null     float64
#  16  2014            19 non-null     float64
# ...

# %%
# Describing (overview) the numerical columns in our dataset 

print(data.describe())
# Out:
#             1999       2000       2001       2002       2003       2004  \
# count  19.000000  19.000000  19.000000  19.000000  19.000000  19.000000
# mean    4.755608   4.714911   4.767756   4.785514   4.935902   4.898488
# std     1.469756   1.434465   1.469833   1.590016   1.550575   1.473691
# min     2.405010   2.400310   2.444770   2.231790   2.610950   2.812620
# 25%     3.962455   3.891930   3.749755   3.644615   3.630330   3.849040
# 50%     4.521680   4.585120   4.817870   4.615200   4.800980   4.730510
# 75%     5.458395   5.421135   5.456305   5.551900   5.775725   5.716005
# max     7.931160   8.084340   8.215450   8.213030   8.121930   8.207630
#
#             2005       2006       2007       2008  ...       2013       2014  \
# count  19.000000  19.000000  19.000000  19.000000  ...  19.000000  19.000000
# mean    4.892433   4.784030   4.691438   4.754596  ...   5.189437   5.208552
# std     1.363092   1.321028   1.313818   1.350918  ...   1.692902   1.526075
# ...

# %%
#Checking For Null values

data.isnull().sum()
# Out:
# Country Name      0
# 1999              0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# Yearly Average    0
# dtype: int64

# %% [markdown]
# ***Performing Further EDA Using Chart***

# %%
# Visualiazion of the total spending by country

plt.figure(figsize=(22, 6))
sns.barplot(data=data, x='Country Name', y='Yearly Average', order=data.sort_values('Yearly Average', ascending=False)['Country Name'])
plt.title('Average Educational Spending by Country')
plt.ylabel('Country')
plt.xlabel('Yearly Average')
plt.xticks(rotation=45)
plt.show()

# %%
# Heatmap of spending across all years

plt.figure(figsize=(12,8))
sns.heatmap(data[years].corr(), cmap='coolwarm', annot=True)
plt.title('correlaton heatmap of educational spending across years')
plt.show()

# %%
#univarariate analysis on the distribution of average spending across different countries

plt.figure(figsize=(10,6))
sns.histplot(data=data, x='Yearly Average', kde=True, bins=5)
plt.title('Distribution of Average Educational Spending ')
plt.xlabel('Average Spending')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(20, 6))
for country in data['Country Name'].unique():
    country_data = data[data['Country Name'] == country]
    plt.plot(country_data.columns[1:-1], country_data.iloc[0, 1:-1], label=country)
plt.title('Education Spending Over Time')
plt.xlabel('Year')
plt.ylabel('Percentage of GDP Spent on Education')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
for country in data['Country Name'].unique():
    country_data = data[data['Country Name'] == country]
    plt.figure(figsize=(20, 6))
    plt.plot(country_data.columns[1:-1], country_data.iloc[0, 1:-1], label=country)
    plt.title(f'Education Spending Over Time - {country}')
    plt.xlabel('Year')
    plt.ylabel('Percentage of GDP Spent on Education')
    plt.legend(loc='upper left')
    plt.show()

# %%
grouped_data = data.drop(columns=['Yearly Average']).groupby('Country Name')

# %%
grouped_data.get_group('Argentina')
# Out:
#   Country Name     1999     2000     2001     2002     2003     2004     2005  \
# 0    Argentina  4.52168  4.58031  4.83374  4.01734  3.53505  3.48652  3.86001
#
#       2006    2007  ...     2012     2013     2014     2015     2016     2017  \
# 0  4.12821  4.4626  ...  5.34583  5.43661  5.36144  5.77611  5.54549  5.45432
#
#       2018    2019     2020    2021
# 0  4.87774  4.7776  5.27964  4.6476
#
# [1 rows x 24 columns]

# %%
data
# Out:
#       Country Name     1999     2000     2001     2002     2003     2004  \
# 0        Argentina  4.52168  4.58031  4.83374  4.01734  3.53505  3.48652
# 1          Austria  6.11234  5.58881  5.57548  5.52213  5.36183  5.30243
# 2      Switzerland  4.75953  4.65878  4.82219  5.17881  5.38401  5.31429
# 3    Cote d'Ivoire  2.68529  2.40031  2.44477  2.81048  2.86437  2.91176
# 4           Cyprus  4.77208  4.98954  5.11552  5.58167  6.67023  6.11772
# 5          Denmark  7.93116  8.08434  8.21545  8.21303  8.12193  8.20763
# 6            Spain  4.26044  4.16605  4.11127  4.13457  4.17343  4.15786
# 7          Finland  5.86993  5.70930  5.84025  6.01678  6.16744  6.15758
# 8   United Kingdom  3.98515  4.01475  4.09869  4.61520  4.80098  4.73051
# 9           Greece  3.02773  3.23019  3.36458  3.42431  3.42934  3.66719
# 10           Italy  4.51085  4.29108  4.65009  4.43241  4.54179  4.38520
# 11           Japan  3.37813  3.46012  3.40082  3.40899  3.46663  3.42611
# ...

# %%
data['Country Name'].to_list()
# Out:
# 19

# %%
data.columns
# Out:
# Index(['Country Name', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Yearly Average'],
#       dtype='object')

# %%
df_trans = data.drop(columns=['Yearly Average']).melt(id_vars=['Country Name'], var_name= 'Year', value_name=" % gdp")

# %%
df_trans
# Out:
#       Country Name  Year     % gdp
# 0        Argentina  1999  4.521680
# 1          Austria  1999  6.112340
# 2      Switzerland  1999  4.759530
# 3    Cote d'Ivoire  1999  2.685290
# 4           Cyprus  1999  4.772080
# ..             ...   ...       ...
# 432    Netherlands  2021  5.135831
# 433         Norway  2021  5.041692
# 434       Portugal  2021  4.711906
# 435         Sweden  2021  6.679961
# 436       Thailand  2021  2.986185
#
# [437 rows x 3 columns]

# %%
df_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  437 non-null    object
#  1   Year          437 non-null    object
#  2    % gdp        437 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 10.4+ KB
